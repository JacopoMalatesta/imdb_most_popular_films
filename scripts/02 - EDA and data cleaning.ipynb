# %% [markdown]
# # Modules and data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
import os
import pickle
import scraping_functions # Let's also import the script with our scraping functions

# %% [markdown]
# Loading the first dataframe (i.e. the one with the API data)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/JacopoMalatesta/imdb_most_popular_films/main/data/df_api.csv",
              index_col = 0,
              dtype = 'object')

# %% [markdown]
# Loading the second dataframe (i.e. the first dataframe of scraped data)

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/JacopoMalatesta/imdb_most_popular_films/main/data/scraped_df_1.csv", 
                  index_col = 0,
                  dtype = 'object')

# %% [markdown]
# Loading the third dataframe (i.e. the second dataframe of scraped data)

# %%
df3 = pd.read_csv("https://raw.githubusercontent.com/JacopoMalatesta/imdb_most_popular_films/main/data/scraped_df_2.csv",
                  index_col = 0,
                  dtype = 'object')

# %% [markdown]
# Let's also load the film IDs

# %%
with open('data/film_ids.txt', 'rb') as f:
    film_ids = pickle.load(f)

# %% [markdown]
# # First datraframe

# %%
df.head()
# Out:
#           id                     title release_date runtime  \
# 0  tt0111161  The Shawshank Redemption   1994-09-23     142
# 1  tt0468569           The Dark Knight   2008-07-14     152
# 2  tt1375666                 Inception   2010-07-15     148
# 3  tt0137523                Fight Club   1999-10-15     139
# 4  tt0109830              Forrest Gump   1994-07-06     142
#
#                                    country          language  \
# 0                 United States of America           English
# 1  United Kingdom;United States of America  English;Mandarin
# 2  United Kingdom;United States of America  English;Japanese
# 3         Germany;United States of America           English
# 4                 United States of America           English
#
#                               genre  \
# 0                       Drama;Crime
# 1       Drama;Action;Crime;Thriller
# 2  Action;Science Fiction;Adventure
# 3                             Drama
# 4              Comedy;Drama;Romance
#
#                                              studios     budget     revenue
# 0                          Castle Rock Entertainment   25000000    28341469
# 1  DC Comics;Legendary Pictures;Syncopy;Isobel Gr...  185000000  1004558444
# 2   Legendary Pictures;Syncopy;Warner Bros. Pictures  160000000   825532764
# 3  Regency Enterprises;Fox 2000 Pictures;Taurus F...   63000000   100853753
# 4                  Paramount;The Steve Tisch Company   55000000   677387716

# %% [markdown]
# All IDs are unique

# %%
df["id"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# We have virtually zero null values

# %%
df.apply(lambda col: col.isnull().sum() / df.shape[0])
# Out:
# id              0.0000
# title           0.0000
# release_date    0.0000
# runtime         0.0000
# country         0.0000
# language        0.0006
# genre           0.0000
# studios         0.0016
# budget          0.0000
# revenue         0.0000
# dtype: float64

# %% [markdown]
# # Second dataframe

# %% [markdown]
# Let's now have a look at second dataframe. This is the first of two datasets containing scraped data.

# %%
df2.head()
# Out:
#           id           director  \
# 0  tt0111161     Frank Darabont
# 1  tt0468569  Christopher Nolan
# 2  tt1375666  Christopher Nolan
# 3  tt0137523      David Fincher
# 4  tt0109830    Robert Zemeckis
#
#                                             writer imdb_rating  \
# 0                      Frank Darabont;Stephen King         9.3
# 1  David S. Goyer;Christopher Nolan;Jonathan Nolan         9.0
# 2                                Christopher Nolan         8.8
# 3                         Chuck Palahniuk;Jim Uhls         8.8
# 4                          Eric Roth;Winston Groom         8.8
#
#   imdb_rating_count metascore user_review_count critic_review_count  color  \
# 0           2508904        80              9750                 190  Color
# 1           2458874        84              7767                 427    NaN
# 2           2205560        74                67                 479  Color
# 3           1973247        66              4131                 366  Color
# 4           1936080        82              2811                 164  Color
#
#   aspect_ratio last_updated
# 0     1.85 : 1   2021-12-22
# 1     2.39 : 1   2021-12-22
# 2     1.85 : 1   2021-12-22
# 3     2.39 : 1   2021-12-22
# 4     2.39 : 1   2021-12-22

# %% [markdown]
# Same number of rows as the dataframe of API data

# %%
df.shape[0] == df2.shape[0]
# Out:
# True

# %% [markdown]
# There's one duplicate ID.

# %%
df2["id"].duplicated().sum()
# Out:
# 1

# %% [markdown]
# This is because we have two null values in the ID column

# %%
df2["id"].isnull().sum()
# Out:
# 2

# %% [markdown]
# 11% of the rows have missing values in the color variable, 7% in the metascore variable

# %%
df2.apply(lambda col: col.isnull().sum() / df2.shape[0]).sort_values(ascending = False)
# Out:
# color                  0.1096
# metascore              0.0708
# aspect_ratio           0.0348
# user_review_count      0.0044
# writer                 0.0038
# critic_review_count    0.0018
# imdb_rating_count      0.0014
# imdb_rating            0.0014
# director               0.0014
# id                     0.0004
# last_updated           0.0000
# dtype: float64

# %% [markdown]
# Are these missing values the result of some mistake we made while scraping or are they actually missing on IMDB?

# %% [markdown]
# The color information is missing from the IMDB pages of these films. So the NAs in this Series are not due to mistakes in the scraping process.

# %%
df2[df2["color"].isnull()]
# Out:
#              id              director  \
# 1     tt0468569     Christopher Nolan
# 9     tt0068646  Francis Ford Coppola
# 10    tt0816692     Christopher Nolan
# 21    tt0076759          George Lucas
# 44    tt0103064         James Cameron
# ...         ...                   ...
# 4960  tt1361336             Tim Story
# 4964  tt0068638         Sam Peckinpah
# 4974  tt0061655        Roman Polanski
# 4981  tt0063518     Franco Zeffirelli
# 4995  tt0057345       Jean-Luc Godard
#
#                                                  writer imdb_rating  \
# 1       David S. Goyer;Christopher Nolan;Jonathan Nolan         9.0
# 9                       Francis Ford Coppola;Mario Puzo         9.2
# 10                     Christopher Nolan;Jonathan Nolan         8.6
# 21                                         George Lucas         8.6
# 44                         William Wisher;James Cameron         8.5
# ...                                                 ...         ...
# 4960        Joseph Barbera;William Hanna;Kevin Costello         5.3
# 4964                           Walter Hill;Jim Thompson         7.4
# 4974                        Roman Polanski;Gérard Brach         7.2
# 4981  Franco Brusati;Masolino D'Amico;William Shakes...         7.6
# 4995                    Alberto Moravia;Jean-Luc Godard         7.6
#
#      imdb_rating_count metascore user_review_count critic_review_count color  \
# 1              2458874        84              7767                 427   NaN
# 9              1728848       100              4727                 249   NaN
# 10             1656264        74              4840                 626   NaN
# 21             1291693        90              2010                 202   NaN
# 44             1045418        75              1421                 302   NaN
# ...                ...       ...               ...                 ...   ...
# 4960             31161        32               669                 144   NaN
# 4964             31115        55               319                  84   NaN
# 4974             31032        56               170                 100   NaN
# 4981             30962        69               230                  38   NaN
# 4995             30876       NaN               135                 146   NaN
#
#      aspect_ratio last_updated
# 1        2.39 : 1   2021-12-22
# 9        1.85 : 1   2021-12-22
# 10       2.39 : 1   2021-12-22
# 21            NaN   2021-12-22
# 44       2.39 : 1   2021-12-22
# ...           ...          ...
# 4960     1.85 : 1   2021-12-22
# 4964     2.35 : 1   2021-12-22
# 4974     2.35 : 1   2021-12-22
# 4981     1.85 : 1   2021-12-22
# 4995     1.66 : 1   2021-12-22
#
# [548 rows x 11 columns]

# %% [markdown]
# Same thing for the 'metascore' Series: the Metascore of the films with missing values in this column is also missing on IMDB.

# %%
df2[df2["metascore"].isnull()]
# Out:
#              id           director  \
# 622   tt1028528  Quentin Tarantino
# 648   tt1028532    Lasse Hallström
# 664   tt0061722                NaN
# 908   tt0032553    Charles Chaplin
# 919   tt0043014       Billy Wilder
# ...         ...                ...
# 4947  tt0038559      Charles Vidor
# 4956  tt2359810      Aanand L. Rai
# 4985  tt2101569          Brin Hill
# 4994  tt3767372     Shoojit Sircar
# 4995  tt0057345    Jean-Luc Godard
#
#                                                writer imdb_rating  \
# 622                                 Quentin Tarantino         7.0
# 648                  Kaneto Shindô;Stephen P. Lindsey         8.1
# 664                                               NaN         NaN
# 908                                   Charles Chaplin         8.4
# 919   Charles Brackett;Billy Wilder;D.M. Marshman Jr.         8.4
# ...                                               ...         ...
# 4947      E.A. Ellington;Marion Parsonnet;Jo Eisinger         7.6
# 4956                                  Himanshu Sharma         7.6
# 4985                                      Joss Whedon         7.0
# 4994                                  Juhi Chaturvedi         7.6
# 4995                  Alberto Moravia;Jean-Luc Godard         7.6
#
#      imdb_rating_count metascore user_review_count critic_review_count  \
# 622             281646       NaN               742                 229
# 648             270182       NaN               568                  95
# 664                NaN       NaN               NaN                 NaN
# 908             215483       NaN               305                 118
# 919             213558       NaN               668                 190
# ...                ...       ...               ...                 ...
# 4947             31279       NaN               187                 103
# 4956             31194       NaN               159                  22
# 4985             30923       NaN                81                  34
# 4994             30877       NaN               132                  37
# 4995             30876       NaN               135                 146
#
#                 color aspect_ratio last_updated
# 622             Color     2.35 : 1   2021-12-22
# 648             Color     1.85 : 1   2021-12-22
# 664               NaN          NaN   2021-12-22
# 908   Black and White     1.37 : 1   2021-12-22
# 919   Black and White     1.37 : 1   2021-12-22
# ...               ...          ...          ...
# 4947  Black and White     1.37 : 1   2021-12-22
# 4956            Color          NaN   2021-12-22
# 4985            Color     1.33 : 1   2021-12-22
# 4994            Color     2.35 : 1   2021-12-22
# 4995              NaN     1.66 : 1   2021-12-22
#
# [354 rows x 11 columns]

# %% [markdown]
# Same thing for the 'aspect_ratio' Series

# %%
df2[df2['aspect_ratio'].isnull()]
# Out:
#              id                  director  \
# 21    tt0076759              George Lucas
# 23    tt0108052          Steven Spielberg
# 27    tt0080684            Irvin Kershner
# 32    tt0088763           Robert Zemeckis
# 57    tt0081505           Stanley Kubrick
# ...         ...                       ...
# 4858  tt1024715               Clark Gregg
# 4896  tt7725596  Amit Ravindernath Sharma
# 4911  tt6485666               Atlee Kumar
# 4920  tt1620719           Abhinav Kashyap
# 4956  tt2359810             Aanand L. Rai
#
#                                                 writer imdb_rating  \
# 21                                        George Lucas         8.6
# 23                     Steven Zaillian;Thomas Keneally         8.9
# 27         Lawrence Kasdan;George Lucas;Leigh Brackett         8.7
# 32                            Bob Gale;Robert Zemeckis         8.5
# 57          Diane Johnson;Stanley Kubrick;Stephen King         8.4
# ...                                                ...         ...
# 4858                       Clark Gregg;Chuck Palahniuk         6.4
# 4896  Jyoti Kapoor;Akshat Ghildial;Shantanu Srivastava         8.0
# 4911     Vijayendra Prasad;Ramanagirivasan;Atlee Kumar         7.8
# 4920                      Abhinav Kashyap;Dilip Shukla         6.2
# 4956                                   Himanshu Sharma         7.6
#
#      imdb_rating_count metascore user_review_count critic_review_count  \
# 21             1291693        90              2010                 202
# 23             1283317        94              2053                 167
# 27             1219988        82              1360                 233
# 32             1129288        87              1362                 257
# 57              959512        66              2062                 350
# ...                ...       ...               ...                 ...
# 4858             32284        47                82                 148
# 4896             31913       NaN               247                  21
# 4911             31740       NaN                28                  13
# 4920             31659       NaN               156                  37
# 4956             31194       NaN               159                  22
#
#                 color aspect_ratio last_updated
# 21                NaN          NaN   2021-12-22
# 23    Black and White          NaN   2021-12-22
# 27              Color          NaN   2021-12-22
# 32              Color          NaN   2021-12-22
# 57              Color          NaN   2021-12-22
# ...               ...          ...          ...
# 4858              NaN          NaN   2021-12-22
# 4896            Color          NaN   2021-12-22
# 4911            Color          NaN   2021-12-22
# 4920            Color          NaN   2021-12-22
# 4956            Color          NaN   2021-12-22
#
# [174 rows x 11 columns]

# %% [markdown]
# ## Filling missing values

# %% [markdown]
# ### Missing films

# %% [markdown]
# For some reason we couldn't scrape any info about seven films.

# %%
df2[df2['director'].isnull()]
# Out:
#              id director writer imdb_rating imdb_rating_count metascore  \
# 664   tt0061722      NaN    NaN         NaN               NaN       NaN
# 991         NaN      NaN    NaN         NaN               NaN       NaN
# 1057  tt0099810      NaN    NaN         NaN               NaN       NaN
# 1376  tt0102138      NaN    NaN         NaN               NaN       NaN
# 3162        NaN      NaN    NaN         NaN               NaN       NaN
# 3172  tt5461944      NaN    NaN         NaN               NaN       NaN
# 4062  tt8368512      NaN    NaN         NaN               NaN       NaN
#
#      user_review_count critic_review_count color aspect_ratio last_updated
# 664                NaN                 NaN   NaN          NaN   2021-12-22
# 991                NaN                 NaN   NaN          NaN   2021-12-22
# 1057               NaN                 NaN   NaN          NaN   2021-12-22
# 1376               NaN                 NaN   NaN          NaN   2021-12-22
# 3162               NaN                 NaN   NaN          NaN   2021-12-22
# 3172               NaN                 NaN   NaN          NaN   2021-12-22
# 4062               NaN                 NaN   NaN          NaN   2021-12-22

# %% [markdown]
# Let's extract the film IDs of the three missing films into a Pandas Series

# %%
missing_film_ids = list(df2[df2['director'].isnull()]['id'])

# %% [markdown]
# Let's fill the two missing IDs

# %%
missing_film_ids[1] = film_ids[991]
missing_film_ids[4] = film_ids[3162]

# %% [markdown]
# Let's fill them in the dataframe as well

# %%
df2.loc[991, 'id'] = film_ids[991]
df2.loc[3162, 'id'] = film_ids[3162]

# %% [markdown]
# Let's scrape those pieces of data again

# %%
for i in range(len(missing_film_ids)):
    
    content = requests.get(f"https://www.imdb.com/title/{missing_film_ids[i]}").content
    soup = BeautifulSoup(content)
    
    df2.loc[df2['id'] == missing_film_ids[i], 'director'] = scraping_functions.scrape_director(soup)
    df2.loc[df2['id'] == missing_film_ids[i], 'writer'] = scraping_functions.scrape_writer(soup)
    df2.loc[df2['id'] == missing_film_ids[i], 'imdb_rating'] = scraping_functions.scrape_imdb_rating(soup)
    df2.loc[df2['id'] == missing_film_ids[i], 'imdb_rating_count'] = scraping_functions.scrape_rating_count(soup)
    df2.loc[df2['id'] == missing_film_ids[i], 'metascore'] = scraping_functions.scrape_metascore(soup)
    df2.loc[df2['id'] == missing_film_ids[i], 'user_review_count'] = scraping_functions.scrape_user_review_count(soup)
    df2.loc[df2['id'] == missing_film_ids[i], 'critic_review_count'] = scraping_functions.scrape_critic_review_count(soup)
    df2.loc[df2['id'] == missing_film_ids[i], 'color'] = scraping_functions.scrape_color(soup)
    df2.loc[df2['id'] == missing_film_ids[i], 'aspect_ratio'] = scraping_functions.scrape_aspect_ratio(soup)

# %% [markdown]
# We successfully scraped the data for all films.

# %%
df2[df2['id'].isin(missing_film_ids)]
# Out:
#              id                director  \
# 664   tt0061722            Mike Nichols
# 991   tt0079817      Sylvester Stallone
# 1057  tt0099810          John McTiernan
# 1376  tt0102138            Oliver Stone
# 3162  tt0060176  Michelangelo Antonioni
# 3172  tt5461944           Anthony Maras
# 4062  tt8368512           Dominic Cooke
#
#                                                  writer imdb_rating  \
# 664           Buck Henry;Charles Webb;Calder Willingham         8.0
# 991                                  Sylvester Stallone         7.3
# 1057        Tom Clancy;Donald E. Stewart;Larry Ferguson         7.6
# 1376                Jim Marrs;Oliver Stone;Jim Garrison         8.0
# 3162  Julio Cortázar;Tonino Guerra;Michelangelo Anto...         7.6
# 3172                          Anthony Maras;John Collee         7.6
# 4062                                       Tom O'Connor         7.2
#
#      imdb_rating_count metascore user_review_count critic_review_count  color  \
# 664             265496        83               820                 189  Color
# 991             201537        61               245                  93    NaN
# 1057            190974        58               329                 116    NaN
# 1376            150318        72               529                  89  Color
# 3162             59866        82               311                 146    NaN
# 3172             59630        62               444                 168  Color
# 4062             42483        65               299                 149  Color
#
#      aspect_ratio last_updated
# 664      1.78 : 1   2021-12-22
# 991           NaN   2021-12-22
# 1057     2.35 : 1   2021-12-22
# 1376     2.39 : 1   2021-12-22
# 3162     1.85 : 1   2021-12-22
# 3172     2.35 : 1   2021-12-22
# 4062     2.39 : 1   2021-12-22

# %% [markdown]
# ### Missing user review counts

# %%
df2[df2['user_review_count'].isnull()]
# Out:
#               id             director  \
# 84     tt1454468       Alfonso Cuarón
# 86     tt0458339         Joe Johnston
# 93     tt2582802      Damien Chazelle
# 109    tt0083658         Ridley Scott
# 110    tt0947798     Darren Aronofsky
# 111    tt0211915   Jean-Pierre Jeunet
# 1180   tt0061852  Wolfgang Reitherman
# 1679   tt0063350     George A. Romero
# 1848   tt1622979         Steven Quale
# 1882  tt10295212        Vishnuvardhan
# 2822   tt6566576         Leigh Janiak
# 3011   tt0808506        Mamoru Hosoda
# 3388   tt3612616         Xavier Dolan
# 4032   tt5073642      Richard Stanley
# 4656  tt11657662         Kwang Il Han
#
#                                                  writer imdb_rating  \
# 84                          Jonás Cuarón;Alfonso Cuarón         7.7
# 86         Joe Simon;Stephen McFeely;Christopher Markus         6.9
# 93                                      Damien Chazelle         8.5
# 109   Philip K. Dick;David Webb Peoples;Hampton Fancher         8.1
# 110         John J. McLaughlin;Mark Heyman;Andres Heinz         8.0
# 111                Guillaume Laurant;Jean-Pierre Jeunet         8.3
# 1180           Ken Anderson;Ralph Wright;Larry Clemmons         7.6
# 1679                     George A. Romero;John A. Russo         7.9
# 1848                     Jeffrey Reddick;Eric Heisserer         5.8
# 1882                                Sandeep Shrivastava         8.7
# 2822              Phil Graziadei;R.L. Stine;Kyle Killen         6.2
# 3011                    Yasutaka Tsutsui;Satoko Okudera         7.7
# 3388                                       Xavier Dolan         8.1
# 4032     Richard Stanley;Scarlett Amaris;H.P. Lovecraft         6.2
# 4656                      Beau DeMayo;Andrzej Sapkowski         7.3
#
#      imdb_rating_count metascore user_review_count critic_review_count  \
# 84              798771        96               NaN                 783
# 86              795242        66               NaN                 562
# 93              778287        88               NaN                 583
# 109             732620        84               NaN                 274
# 110             731790        79               NaN                 687
# 111             731124        69               NaN                 147
# 1180            174666        65               NaN                 118
# 1679            123932        89               NaN                 232
# 1848            112379        50               NaN                 279
# 1882            109992       NaN               NaN                  25
# 2822             70021        67               NaN                 169
# 3011             63884       NaN               NaN                  79
# 3388             54683        74               NaN                 259
# 4032             42835        70               NaN                 294
# 4656             34571        67               NaN                  30
#
#                 color aspect_ratio last_updated
# 84                NaN     2.39 : 1   2021-12-22
# 86                NaN     2.39 : 1   2021-12-22
# 93                NaN     2.39 : 1   2021-12-22
# 109               NaN     2.39 : 1   2021-12-22
# 110               NaN     2.35 : 1   2021-12-22
# 111               NaN     2.39 : 1   2021-12-22
# 1180            Color          NaN   2021-12-22
# 1679  Black and White          NaN   2021-12-22
# 1848            Color          NaN   2021-12-22
# 1882            Color          NaN   2021-12-22
# 2822            Color          NaN   2021-12-22
# 3011            Color          NaN   2021-12-22
# 3388            Color          NaN   2021-12-22
# 4032            Color          NaN   2021-12-22
# 4656              NaN          NaN   2021-12-22

# %% [markdown]
# Let's extract the IDs of these films in a Pandas series

# %%
missing_user_review_ids = df2.loc[df2["user_review_count"].isnull(), "id"]

# %% [markdown]
# Let's scrape the user review count again

# %%
for i in range(len(missing_user_review_ids)):
    content = requests.get(f"https://www.imdb.com/title/{missing_user_review_ids.iloc[i]}").content
    soup = BeautifulSoup(content)
    
    df2.loc[df2['id'] == missing_user_review_ids.iloc[i], 'user_review_count'] = scraping_functions.scrape_user_review_count(soup)

# %% [markdown]
# We managed to retrieve the user review count for all those films.

# %%
df2[df2["id"].isin(missing_user_review_ids)]
# Out:
#               id             director  \
# 84     tt1454468       Alfonso Cuarón
# 86     tt0458339         Joe Johnston
# 93     tt2582802      Damien Chazelle
# 109    tt0083658         Ridley Scott
# 110    tt0947798     Darren Aronofsky
# 111    tt0211915   Jean-Pierre Jeunet
# 1180   tt0061852  Wolfgang Reitherman
# 1679   tt0063350     George A. Romero
# 1848   tt1622979         Steven Quale
# 1882  tt10295212        Vishnuvardhan
# 2822   tt6566576         Leigh Janiak
# 3011   tt0808506        Mamoru Hosoda
# 3388   tt3612616         Xavier Dolan
# 4032   tt5073642      Richard Stanley
# 4656  tt11657662         Kwang Il Han
#
#                                                  writer imdb_rating  \
# 84                          Jonás Cuarón;Alfonso Cuarón         7.7
# 86         Joe Simon;Stephen McFeely;Christopher Markus         6.9
# 93                                      Damien Chazelle         8.5
# 109   Philip K. Dick;David Webb Peoples;Hampton Fancher         8.1
# 110         John J. McLaughlin;Mark Heyman;Andres Heinz         8.0
# 111                Guillaume Laurant;Jean-Pierre Jeunet         8.3
# 1180           Ken Anderson;Ralph Wright;Larry Clemmons         7.6
# 1679                     George A. Romero;John A. Russo         7.9
# 1848                     Jeffrey Reddick;Eric Heisserer         5.8
# 1882                                Sandeep Shrivastava         8.7
# 2822              Phil Graziadei;R.L. Stine;Kyle Killen         6.2
# 3011                    Yasutaka Tsutsui;Satoko Okudera         7.7
# 3388                                       Xavier Dolan         8.1
# 4032     Richard Stanley;Scarlett Amaris;H.P. Lovecraft         6.2
# 4656                      Beau DeMayo;Andrzej Sapkowski         7.3
#
#      imdb_rating_count metascore user_review_count critic_review_count  \
# 84              798771        96              2206                 783
# 86              795242        66              1006                 562
# 93              778287        88              1429                 583
# 109             732620        84              1675                 274
# 110             731790        79              1379                 687
# 111             731124        69              1549                 147
# 1180            174666        65              3555                 118
# 1679            123932        89               710                 232
# 1848            112379        50               192                 279
# 1882            109992       NaN              3089                  25
# 2822             70021        67               891                 169
# 3011             63884       NaN               108                  79
# 3388             54683        74                93                 259
# 4032             42835        70               632                 294
# 4656             34571        67               280                  30
#
#                 color aspect_ratio last_updated
# 84                NaN     2.39 : 1   2021-12-22
# 86                NaN     2.39 : 1   2021-12-22
# 93                NaN     2.39 : 1   2021-12-22
# 109               NaN     2.39 : 1   2021-12-22
# 110               NaN     2.35 : 1   2021-12-22
# 111               NaN     2.39 : 1   2021-12-22
# 1180            Color          NaN   2021-12-22
# 1679  Black and White          NaN   2021-12-22
# 1848            Color          NaN   2021-12-22
# 1882            Color          NaN   2021-12-22
# 2822            Color          NaN   2021-12-22
# 3011            Color          NaN   2021-12-22
# 3388            Color          NaN   2021-12-22
# 4032            Color          NaN   2021-12-22
# 4656              NaN          NaN   2021-12-22

# %% [markdown]
# These are the % of null values now

# %%
df2.apply(lambda x: x.isnull().sum() / df2.shape[0]).sort_values(ascending=False)
# Out:
# color                  0.1088
# metascore              0.0694
# aspect_ratio           0.0336
# writer                 0.0024
# critic_review_count    0.0004
# last_updated           0.0000
# user_review_count      0.0000
# imdb_rating_count      0.0000
# imdb_rating            0.0000
# director               0.0000
# id                     0.0000
# dtype: float64

# %% [markdown]
# # Third dataframe

# %%
df3.apply(lambda x: x.isnull().sum() / df3.shape[0]).sort_values(ascending=False)
# Out:
# art_director           0.1236
# costume_designer       0.1098
# production_designer    0.0912
# composer               0.0438
# cinematographer        0.0278
# editor                 0.0046
# producers              0.0014
# actors                 0.0000
# id                     0.0000
# dtype: float64

# %% [markdown]
# No duplicate IDs

# %%
df['id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Films with missing 'cinematographer' are mostly animated films (which do not have a cinematographer)

# %%
df3[df3['cinematographer'].isnull()]
# Out:
#              id                                             actors  \
# 50    tt0110357  Rowan Atkinson;Matthew Broderick;Niketa Calame...
# 52    tt1049413  Ed Asner;Christopher Plummer;Jordan Nagai;Bob ...
# 62    tt0114709  Tom Hanks;Tim Allen;Don Rickles;Jim Varney;Wal...
# 72    tt0198781  John Goodman;Billy Crystal;Mary Gibbs;Steve Bu...
# 87    tt0435761  Tom Hanks;Tim Allen;Joan Cusack;Ned Beatty;Don...
# ...         ...                                                ...
# 4676  tt0485601  Evan McGuire;Christen Mooney;Brendan Gleeson;M...
# 4723  tt0082509  Don Francks;Caroline Semple;Richard Romanus;Su...
# 4729  tt3666024  Emmanuel Garijo;Tom Hudson;Baptiste Goy;Axel D...
# 4763  tt0066473  Martin Balsam;Sô Yamamura;Jason Robards;Joseph...
# 4807  tt7905466  Thomas Adlam;William Argent;John Ashby;Attwood...
#
#      cinematographer                                            editor  \
# 50               NaN                                     Ivan Bilancio
# 52               NaN                                     Kevin Nolting
# 62               NaN                         Robert Gordon;Lee Unkrich
# 72               NaN                                       Jim Stewart
# 87               NaN                                   Ken Schretzmann
# ...              ...                                               ...
# 4676             NaN                             Fabienne Alvarez-Giro
# 4723             NaN              Ian Llande;Mick Manning;Gerald Tripp
# 4729             NaN                                  Céline Kélépikis
# 4763             NaN  Pembroke J. Herring;Shinya Inoue;James E. Newcom
# 4807             NaN                                      Jabez Olssen
#
#                    composer  \
# 50              Hans Zimmer
# 52        Michael Giacchino
# 62             Randy Newman
# 72             Randy Newman
# 87             Randy Newman
# ...                     ...
# 4676          Bruno Coulais
# 4723        Elmer Bernstein
# 4729  Laurent Perez Del Mar
# 4763        Jerry Goldsmith
# 4807                 Plan 9
#
#                                               producers  \
# 50    Alice Dewey Goldstone;Don Hahn;Sarah McArthur;...
# 52    John Lasseter;Kori Rae;Denise Ream;Jonas River...
# 62    Bonnie Arnold;Ed Catmull;Ralph Guggenheim;Stev...
# 72    Darla K. Anderson;Karen Dufilho-Rosen;John Las...
# 87    Darla K. Anderson;John Lasseter;Nicole Paradis...
# ...                                                 ...
# 4676  Didier Brunner;James Flynn;Tomm Moore;Ivan Rou...
# 4723  Vic Atkinson;John Coates;Michael C. Gross;John...
# 4729  Rémi Burah;Pascal Caucheteux;Christophe Jankov...
# 4763  Richard Fleischer;Keinosuke Kubo;Otto Lang;Mas...
# 4807  Peter Jackson;Ken Kamins;Clare Olssen;Tessa Ro...
#
#            production_designer  \
# 50               Chris Sanders
# 52                Ricky Nierva
# 62                         NaN
# 72    Harley Jessup;Bob Pauley
# 87                  Bob Pauley
# ...                        ...
# 4676                       NaN
# 4723          Michael C. Gross
# 4729      Michael Dudok de Wit
# 4763                       NaN
# 4807                       NaN
#
#                                            art_director costume_designer
# 50                                         Andy Gaskill              NaN
# 52                                   Daniel Lopez Muñoz              NaN
# 62                                      Ralph Eggleston              NaN
# 72                       Tia W. Kratter;Dominique Louis              NaN
# 87    Daniel Arriaga;Robert Kondo;Daisuke 'Dice' Tsu...              NaN
# ...                                                 ...              ...
# 4676                                       Ross Stewart              NaN
# 4723                                          Pat Gavin              NaN
# 4729                                                NaN              NaN
# 4763  Richard Day;Taizô Kawashima;Yoshirô Muraki;Jac...              NaN
# 4807                                                NaN              NaN
#
# [139 rows x 9 columns]

# %% [markdown]
# # Joining the dataframes

# %% [markdown]
# Let's join the second dataframe to the first one by using the film id as our key. They have exactly the same IDs so a left, inner and right join would all result in the same result.

# %%
cleaned_df = pd.merge(left = df, right = df2, how = 'inner', on = 'id')

# %% [markdown]
# Let's now join the third dataframe to the other two.

# %%
cleaned_df = pd.merge(left = cleaned_df, right = df3, how = 'inner', on = 'id')

# %% [markdown]
# Let's have a look at the output

# %%
cleaned_df.head()
# Out:
#           id                     title release_date runtime  \
# 0  tt0111161  The Shawshank Redemption   1994-09-23     142
# 1  tt0468569           The Dark Knight   2008-07-14     152
# 2  tt1375666                 Inception   2010-07-15     148
# 3  tt0137523                Fight Club   1999-10-15     139
# 4  tt0109830              Forrest Gump   1994-07-06     142
#
#                                    country          language  \
# 0                 United States of America           English
# 1  United Kingdom;United States of America  English;Mandarin
# 2  United Kingdom;United States of America  English;Japanese
# 3         Germany;United States of America           English
# 4                 United States of America           English
#
#                               genre  \
# 0                       Drama;Crime
# 1       Drama;Action;Crime;Thriller
# 2  Action;Science Fiction;Adventure
# 3                             Drama
# 4              Comedy;Drama;Romance
#
#                                              studios     budget     revenue  \
# 0                          Castle Rock Entertainment   25000000    28341469
# 1  DC Comics;Legendary Pictures;Syncopy;Isobel Gr...  185000000  1004558444
# 2   Legendary Pictures;Syncopy;Warner Bros. Pictures  160000000   825532764
# 3  Regency Enterprises;Fox 2000 Pictures;Taurus F...   63000000   100853753
# 4                  Paramount;The Steve Tisch Company   55000000   677387716
#
#    ... aspect_ratio last_updated  \
# 0  ...     1.85 : 1   2021-12-22
# 1  ...     2.39 : 1   2021-12-22
# 2  ...     1.85 : 1   2021-12-22
# 3  ...     2.39 : 1   2021-12-22
# 4  ...     2.39 : 1   2021-12-22
#
#                                               actors  cinematographer  \
# 0  Tim Robbins;Morgan Freeman;Bob Gunton;William ...    Roger Deakins
# 1  Christian Bale;Heath Ledger;Aaron Eckhart;Mich...    Wally Pfister
# 2  Leonardo DiCaprio;Joseph Gordon-Levitt;Elliot ...    Wally Pfister
# 3  Edward Norton;Brad Pitt;Meat Loaf;Zach Grenier...  Jeff Cronenweth
# 4  Tom Hanks;Rebecca Williams;Sally Field;Michael...      Don Burgess
#
#                   editor                                 composer  \
# 0  Richard Francis-Bruce                            Thomas Newman
# 1              Lee Smith          James Newton Howard;Hans Zimmer
# 2              Lee Smith                              Hans Zimmer
# 3          James Haygood  Dust Brothers;John King;Michael Simpson
# 4         Arthur Schmidt                           Alan Silvestri
#
#                                            producers   production_designer  \
# 0            Liz Glotzer;David V. Lester;Niki Marvin  Terence Marsh;Soheil
# 1  Kevin de la Noy;Jordan Goldberg;Philip Lee;Ben...        Nathan Crowley
# 2  Zakaria Alaoui;John Bernard;Chris Brigham;Jord...      Guy Hendrix Dyas
# 3  Ross Grayson Bell;Ceán Chaffin;John S. Dorsey;...         Alex McDowell
# 4  Wendy Finerman;Charles Newirth;Steve Starkey;S...           Rick Carter
#
#                                         art_director   costume_designer
# 0                              Peter Landsdown Smith  Elizabeth McBride
# 1  Mark Bartholomew;James Hambidge;Craig Jackson;...      Lindy Hemming
# 2  Luke Freeborn;Matthew Gray;Brad Ricker;Dean Wo...    Jeffrey Kurland
# 3                         Melique Berger;Chris Gorak     Michael Kaplan
# 4            Leslie McDonald;William James Teegarden    Joanna Johnston
#
# [5 rows x 28 columns]

# %% [markdown]
# We ended up with the right number of rows

# %%
cleaned_df.shape
# Out:
# (5000, 28)

# %%
cleaned_df.columns
# Out:
# Index(['id', 'title', 'release_date', 'runtime', 'country', 'language',
#        'genre', 'studios', 'budget', 'revenue', 'director', 'writer',
#        'imdb_rating', 'imdb_rating_count', 'metascore', 'user_review_count',
#        'critic_review_count', 'color', 'aspect_ratio', 'last_updated',
#        'actors', 'cinematographer', 'editor', 'composer', 'producers',
#        'production_designer', 'art_director', 'costume_designer'],
#       dtype='object')

# %%
cleaned_df = cleaned_df.reindex(columns= ['id', 'title', 'release_date', 'runtime', 'country', 'language', 'genre', 'studios',
                             'color', 'aspect_ratio', 'budget', 'revenue', 'imdb_rating', 'imdb_rating_count', 
                             'metascore', 'user_review_count', 'critic_review_count', 'director', 'writer', 
                             'actors', 'cinematographer', 'editor', 'composer', 'production_designer', 'art_director',
                             'costume_designer', 'producers', 'last_updated'])

# %% [markdown]
# # Casting

# %% [markdown]
# Right now all the columns are of the 'object' type. We need to cast them to the correct dtype.

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   5000 non-null   object
#  1   title                5000 non-null   object
#  2   release_date         5000 non-null   object
#  3   runtime              5000 non-null   object
#  4   country              5000 non-null   object
#  5   language             4997 non-null   object
#  6   genre                5000 non-null   object
#  7   studios              4992 non-null   object
#  8   budget               5000 non-null   object
#  9   revenue              5000 non-null   object
#  10  director             5000 non-null   object
#  11  writer               4988 non-null   object
#  12  imdb_rating          5000 non-null   object
#  13  imdb_rating_count    5000 non-null   object
#  14  metascore            4653 non-null   object
#  15  user_review_count    5000 non-null   object
#  16  critic_review_count  4998 non-null   object
#  17  color                4456 non-null   object
#  18  aspect_ratio         4832 non-null   object
#  19  last_updated         5000 non-null   object
#  20  actors               5000 non-null   object
#  21  cinematographer      4861 non-null   object
#  22  editor               4977 non-null   object
#  23  composer             4781 non-null   object
#  24  producers            4993 non-null   object
#  25  production_designer  4544 non-null   object
#  26  art_director         4382 non-null   object
#  27  costume_designer     4451 non-null   object
# dtypes: object(28)
# memory usage: 1.1+ MB

# %% [markdown]
# Let's first cast the following columns to integers. The ones with missing values will actually be cast to floats.

# %%
integer_cols = ['runtime', 'budget', 'revenue', 'imdb_rating_count', 'metascore', 'user_review_count', 'critic_review_count']

cleaned_df[integer_cols] = cleaned_df[integer_cols].apply(lambda x: pd.to_numeric(arg = x, downcast='integer'))

# %% [markdown]
# Let's cast the release date to a datetime variable

# %%
cleaned_df[['release_date', 'last_updated']] = cleaned_df[['release_date', 'last_updated']].apply(pd.to_datetime)

# %% [markdown]
# Let's cast the IMDB avg rating to float

# %%
cleaned_df['imdb_rating'] = pd.to_numeric(cleaned_df['imdb_rating'])

# %% [markdown]
# Everything looks fine

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   5000 non-null   object
#  1   title                5000 non-null   object
#  2   release_date         5000 non-null   datetime64[ns]
#  3   runtime              5000 non-null   int16
#  4   country              5000 non-null   object
#  5   language             4997 non-null   object
#  6   genre                5000 non-null   object
#  7   studios              4992 non-null   object
#  8   budget               5000 non-null   int32
#  9   revenue              5000 non-null   int64
#  10  director             5000 non-null   object
#  11  writer               4988 non-null   object
#  12  imdb_rating          5000 non-null   float64
#  13  imdb_rating_count    5000 non-null   int32
#  14  metascore            4653 non-null   float64
#  15  user_review_count    5000 non-null   int16
#  16  critic_review_count  4998 non-null   float64
#  17  color                4456 non-null   object
#  18  aspect_ratio         4832 non-null   object
#  19  last_updated         5000 non-null   datetime64[ns]
#  20  actors               5000 non-null   object
#  21  cinematographer      4861 non-null   object
#  22  editor               4977 non-null   object
#  23  composer             4781 non-null   object
#  24  producers            4993 non-null   object
#  25  production_designer  4544 non-null   object
#  26  art_director         4382 non-null   object
#  27  costume_designer     4451 non-null   object
# dtypes: datetime64[ns](2), float64(3), int16(2), int32(2), int64(1), object(18)
# memory usage: 1.0+ MB

# %% [markdown]
# # Saving the cleaned dataframes

# %%
cleaned_df.to_csv("data/cleaned_df.csv")
