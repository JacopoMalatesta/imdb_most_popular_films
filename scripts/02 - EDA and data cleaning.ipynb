# %% [markdown]
# # Modules and data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
import os

# %% [markdown]
# Loading the first dataframe (i.e. the one with the API data)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/JacopoMalatesta/imdb_most_popular_films/main/data/df_api.csv",
              index_col = 0,
              dtype = 'object')

# %% [markdown]
# Loading the second dataframe (i.e. the first dataframe of scraped data)

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/JacopoMalatesta/imdb_most_popular_films/main/data/scraped_df_1.csv", 
                  index_col = 0,
                  dtype = 'object')

# %% [markdown]
# Loading the third dataframe (i.e. the second dataframe of scraped data)

# %%
df3 = pd.read_csv("https://raw.githubusercontent.com/JacopoMalatesta/imdb_most_popular_films/main/data/scraped_df_2.csv",
                  index_col = 0,
                  dtype = 'object')

# %% [markdown]
# # First datraframe

# %%
df.head()
# Out:
#           id                     title release_date runtime  \
# 0  tt0111161  The Shawshank Redemption   1994-09-23     142
# 1  tt0468569           The Dark Knight   2008-07-14     152
# 2  tt1375666                 Inception   2010-07-15     148
# 3  tt0137523                Fight Club   1999-10-15     139
# 4  tt0109830              Forrest Gump   1994-07-06     142
#
#                                    country          language  \
# 0                 United States of America           English
# 1  United Kingdom;United States of America  English;Mandarin
# 2  United Kingdom;United States of America  English;Japanese
# 3         Germany;United States of America           English
# 4                 United States of America           English
#
#                               genre  \
# 0                       Drama;Crime
# 1       Drama;Action;Crime;Thriller
# 2  Action;Science Fiction;Adventure
# 3                             Drama
# 4              Comedy;Drama;Romance
#
#                                              studios     budget     revenue
# 0                          Castle Rock Entertainment   25000000    28341469
# 1  DC Comics;Legendary Pictures;Syncopy;Isobel Gr...  185000000  1004558444
# 2   Legendary Pictures;Syncopy;Warner Bros. Pictures  160000000   825532764
# 3  Regency Enterprises;Fox 2000 Pictures;Taurus F...   63000000   100853753
# 4                  Paramount;The Steve Tisch Company   55000000   677387716

# %% [markdown]
# All IDs are unique

# %%
df["id"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# We have virtually zero null values

# %%
df.apply(lambda col: col.isnull().sum() / df.shape[0])
# Out:
# id              0.0000
# title           0.0000
# release_date    0.0000
# runtime         0.0000
# country         0.0000
# language        0.0006
# genre           0.0000
# studios         0.0016
# budget          0.0000
# revenue         0.0000
# dtype: float64

# %% [markdown]
# # Second dataframe

# %% [markdown]
# Let's now have a look at second dataframe. This is the first of two datasets containing scraped data.

# %%
df2.head()
# Out:
#           id           director  \
# 0  tt0111161     Frank Darabont
# 1  tt0468569  Christopher Nolan
# 2  tt1375666  Christopher Nolan
# 3  tt0137523      David Fincher
# 4  tt0109830    Robert Zemeckis
#
#                                             writer imdb_rating  \
# 0                      Stephen King;Frank Darabont         9.3
# 1  David S. Goyer;Jonathan Nolan;Christopher Nolan         9.0
# 2                                Christopher Nolan         8.8
# 3                         Jim Uhls;Chuck Palahniuk         8.8
# 4                          Winston Groom;Eric Roth         8.8
#
#   imdb_rating_count metascore user_review_count critic_review_count  color  \
# 0           2506833        80              9750                 190  Color
# 1           2456425        84              7764                 427    NaN
# 2           2203914        74              4466                 479  Color
# 3           1971788        66              4127                 366  Color
# 4           1934719        82              2807                 164  Color
#
#   aspect_ratio
# 0     1.85 : 1
# 1     2.39 : 1
# 2     2.39 : 1
# 3     2.39 : 1
# 4     2.39 : 1

# %% [markdown]
# Same number of rows as the dataframe of API data

# %%
df.shape[0] == df2.shape[0]
# Out:
# True

# %% [markdown]
# No duplicated IDs

# %%
df2["id"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# 12% of the rows have missing values in the color variable, 7% in the metascore variable

# %%
df2.apply(lambda col: col.isnull().sum() / df2.shape[0]).sort_values(ascending = False)
# Out:
# color                  0.1182
# metascore              0.0698
# aspect_ratio           0.0334
# writer                 0.0030
# user_review_count      0.0020
# critic_review_count    0.0010
# imdb_rating_count      0.0006
# imdb_rating            0.0006
# director               0.0006
# id                     0.0000
# dtype: float64

# %% [markdown]
# Are these missing values the result of some mistake we made while scraping or are they actually missing on IMDB website?

# %% [markdown]
# If we open the pages of the films with missing values in the 'color' variable we can see that the color information is missing. So the missing values in this Series are not due to mistakes in the scraping process.

# %%
df2[df2["color"].isnull()]
# Out:
#              id              director  \
# 1     tt0468569     Christopher Nolan
# 9     tt0068646  Francis Ford Coppola
# 10    tt0816692     Christopher Nolan
# 21    tt0076759          George Lucas
# 45    tt0114814          Bryan Singer
# ...         ...                   ...
# 4957  tt0033045        Ernst Lubitsch
# 4963  tt0068638         Sam Peckinpah
# 4964  tt1361336             Tim Story
# 4981  tt0063518     Franco Zeffirelli
# 4995  tt0057345       Jean-Luc Godard
#
#                                                  writer imdb_rating  \
# 1       David S. Goyer;Jonathan Nolan;Christopher Nolan         9.0
# 9                       Francis Ford Coppola;Mario Puzo         9.2
# 10                     Jonathan Nolan;Christopher Nolan         8.6
# 21                                         George Lucas         8.6
# 45                                Christopher McQuarrie         8.5
# ...                                                 ...         ...
# 4957          Samson Raphaelson;Ben Hecht;Miklós László         8.1
# 4963                           Jim Thompson;Walter Hill         7.4
# 4964        Joseph Barbera;Kevin Costello;William Hanna         5.3
# 4981  Masolino D'Amico;Franco Brusati;William Shakes...         7.6
# 4995                    Jean-Luc Godard;Alberto Moravia         7.6
#
#      imdb_rating_count metascore user_review_count critic_review_count color  \
# 1              2456425        84              7764                 427   NaN
# 9              1727603       100              4728                 249   NaN
# 10             1654589        74              4838                 626   NaN
# 21             1290992        90              2011                 202   NaN
# 45             1039305        77              1447                 147   NaN
# ...                ...       ...               ...                 ...   ...
# 4957             31144        96               173                  82   NaN
# 4963             31105        55               162                  84   NaN
# 4964             31093        32               669                 144   NaN
# 4981             30939        69               230                  38   NaN
# 4995             30863       NaN               135                 146   NaN
#
#      aspect_ratio
# 1        2.39 : 1
# 9        1.85 : 1
# 10       2.39 : 1
# 21            NaN
# 45       2.39 : 1
# ...           ...
# 4957     1.37 : 1
# 4963     2.35 : 1
# 4964     1.85 : 1
# 4981     1.85 : 1
# 4995     2.35 : 1
#
# [591 rows x 10 columns]

# %% [markdown]
# Same thing for the 'metascore' Series: the Metascore of the films with missing values in this column is also missing on IMDB.

# %%
df2[df2["metascore"].isnull()]
# Out:
#              id           director  \
# 559   tt0448115                NaN
# 622   tt1028528  Quentin Tarantino
# 648   tt1028532    Lasse Hallström
# 906   tt0032553    Charles Chaplin
# 918   tt0043014       Billy Wilder
# ...         ...                ...
# 4947  tt0038559      Charles Vidor
# 4955  tt2359810      Aanand L. Rai
# 4983  tt2101569          Brin Hill
# 4991  tt3767372     Shoojit Sircar
# 4995  tt0057345    Jean-Luc Godard
#
#                                                writer imdb_rating  \
# 559                                               NaN         NaN
# 622                                 Quentin Tarantino         7.0
# 648                  Kaneto Shindô;Stephen P. Lindsey         8.1
# 906                                   Charles Chaplin         8.4
# 918   Charles Brackett;D.M. Marshman Jr.;Billy Wilder         8.4
# ...                                               ...         ...
# 4947      Marion Parsonnet;E.A. Ellington;Jo Eisinger         7.6
# 4955                                  Himanshu Sharma         7.6
# 4983                                      Joss Whedon         7.0
# 4991                                  Juhi Chaturvedi         7.6
# 4995                  Jean-Luc Godard;Alberto Moravia         7.6
#
#      imdb_rating_count metascore user_review_count critic_review_count  color  \
# 559                NaN       NaN               NaN                 NaN    NaN
# 622             281554       NaN               742                 229  Color
# 648             270004       NaN               568                  95  Color
# 906             215387       NaN               305                 118    NaN
# 918             213461       NaN               668                 190    NaN
# ...                ...       ...               ...                 ...    ...
# 4947             31257       NaN               187                 103  Color
# 4955             31175       NaN               159                  22  Color
# 4983             30920       NaN                81                  34  Color
# 4991             30869       NaN               132                  37  Color
# 4995             30863       NaN               135                 146    NaN
#
#      aspect_ratio
# 559           NaN
# 622      2.35 : 1
# 648      1.85 : 1
# 906      1.37 : 1
# 918      1.37 : 1
# ...           ...
# 4947     1.37 : 1
# 4955          NaN
# 4983          NaN
# 4991     2.35 : 1
# 4995     2.35 : 1
#
# [349 rows x 10 columns]

# %% [markdown]
# Same thing for the 'aspect_ratio' Series

# %%
df2[df2['aspect_ratio'].isnull()]
# Out:
#              id                      director  \
# 21    tt0076759                  George Lucas
# 23    tt0108052              Steven Spielberg
# 27    tt0080684                Irvin Kershner
# 32    tt0088763               Robert Zemeckis
# 49    tt0086190              Richard Marquand
# ...         ...                           ...
# 4901  tt0827503  Cem Yilmaz;Ali Taner Baltaci
# 4910  tt6485666                   Atlee Kumar
# 4955  tt2359810                 Aanand L. Rai
# 4972  tt1772288                  Dan Fogelman
# 4983  tt2101569                     Brin Hill
#
#                                              writer imdb_rating  \
# 21                                     George Lucas         8.6
# 23                  Thomas Keneally;Steven Zaillian         8.9
# 27      Lawrence Kasdan;George Lucas;Leigh Brackett         8.7
# 32                         Robert Zemeckis;Bob Gale         8.5
# 49                     Lawrence Kasdan;George Lucas         8.3
# ...                                             ...         ...
# 4901                                     Cem Yilmaz         7.4
# 4910  Vijayendra Prasad;Atlee Kumar;Ramanagirivasan         7.8
# 4955                                Himanshu Sharma         7.6
# 4972                                   Dan Fogelman         7.0
# 4983                                    Joss Whedon         7.0
#
#      imdb_rating_count metascore user_review_count critic_review_count  color  \
# 21             1290992        90              2011                 202    NaN
# 23             1282467        94              2052                 167  Color
# 27             1219238        82                12                 233  Color
# 32             1128514        87              1361                 256  Color
# 49              997245        58               920                 206  Color
# ...                ...       ...               ...                 ...    ...
# 4901             31833       NaN               NaN                   5    NaN
# 4910             31710       NaN               120                  13  Color
# 4955             31175       NaN               159                  22  Color
# 4972             31058        58               125                 151  Color
# 4983             30920       NaN                81                  34  Color
#
#      aspect_ratio
# 21            NaN
# 23            NaN
# 27            NaN
# 32            NaN
# 49            NaN
# ...           ...
# 4901          NaN
# 4910          NaN
# 4955          NaN
# 4972          NaN
# 4983          NaN
#
# [167 rows x 10 columns]

# %% [markdown]
# ## Filling missing values

# %% [markdown]
# ### Missing films

# %% [markdown]
# For some reason we couldn't scrape any info about three films.

# %%
df2[df2['director'].isnull()]
# Out:
#               id director writer imdb_rating imdb_rating_count metascore  \
# 559    tt0448115      NaN    NaN         NaN               NaN       NaN
# 4609   tt9354842      NaN    NaN         NaN               NaN       NaN
# 4704  tt11045422      NaN    NaN         NaN               NaN       NaN
#
#      user_review_count critic_review_count color aspect_ratio
# 559                NaN                 NaN   NaN          NaN
# 4609               NaN                 NaN   NaN          NaN
# 4704               NaN                 NaN   NaN          NaN

# %% [markdown]
# Let's extract the film IDs of the three missing films into a Pandas Series

# %%
missing_film_ids = df2[df2['director'].isnull()]['id']

# %% [markdown]
# Let's recreate the functions we used to scrape the data

# %%
# Film ID
def scrape_film_id(soup):
    
    try:
        film_id = soup.find("meta", {"property": "imdb:pageConst"}).get("content")
    except:
        return np.nan
    else:
        return film_id
# Directors
def scrape_director(soup):
    
    try:  
        a_tags = soup.find_all(href = re.compile("tt_ov_dr"), class_="ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link")
    
        directors = list(set([a.text for a in a_tags]))
    
        directors = ';'.join(directors)
        
    except:
        return np.nan
        
    else:
        return directors
# Writers
def scrape_writer(soup):
    
    try:
        a_tags = soup.find_all(href = re.compile("tt_ov_wr"), class_="ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link")
        
        writers = list(set([a.text for a in a_tags]))
        
        writers = ';'.join(writers)
        
    except:
        return np.nan
        
    else:
        return writers
# IMDB average rating
def scrape_imdb_rating(soup):
    
    try:   
        span = soup.find_all("span", class_="AggregateRatingButton__RatingScore-sc-1ll29m0-1 iTLWoV")[0]
    
        imdb_rating = span.text
        
    except:
        return np.nan
    
    else:
        return imdb_rating
        
# IMDB rating count
def scrape_rating_count(soup):
    
    try:
        pattern = r'(?<="ratingCount":)[\d.]+'
        string = str(soup.find("script", {"type": "application/ld+json"}))
        rating_count = re.findall(pattern = pattern, string = string)[0]
        
    except:
        return np.nan
    
    else:
        return rating_count
# Metascore
def scrape_metascore(soup):
    
    try:
        metascore = soup.find("span", class_="score-meta").text 
    
    except:
        return np.nan
    
    else:
        return metascore
# User review count
def scrape_user_review_count(soup):
    
    try: 
        pattern = r'(?<="total":)\d+(?=,"__typename":"ReviewsConnection"},"criticReviewsTotal":)'
  
        string = str(soup.find("script", {'id': '__NEXT_DATA__'}))
    
        user_review_count = re.findall(pattern = pattern, string = string)[0]
        
    except:
        return np.nan
    
    else:
        return user_review_count
# Critic review count
def scrape_critic_review_count(soup):
    
    try:   
        spans = soup.find_all("span", class_= re.compile("three-Elements")) 
        
        string = list(filter(lambda x: 'Critic' in str(x), spans))[0].text
        
        critic_review_count = re.findall(r'\d+', string)[0]
    
    except:
        return np.nan
        
    else:
        return critic_review_count
# Color
def scrape_color(soup):
    
    try:
        pattern = r'(?<="text":")\w+(?=","attributes":\[\],"__typename":"Coloration"})'
        
        string = str(soup.find("script", {"type": "application/json"}))
    
        color = re.findall(pattern = pattern, string = string)[0]
        
    except:
        return np.nan
    
    else:
        return color
# Aspect ratio
def scrape_aspect_ratio(soup):
    try:
        pattern = r'(?<="aspectRatio":")[\d.\s:]+'
    
        string = str(soup.find("script", {"type": "application/json"}))
    
        aspect_ratio = re.findall(pattern = pattern, string = string)[0] 
        
    except:
        return np.nan
        
    else:
        return aspect_ratio

# %% [markdown]
# Let's scrape those pieces of data again

# %%
for i in range(len(missing_film_ids)):
    
    content = requests.get(f"https://www.imdb.com/title/{missing_film_ids.iloc[i]}").content
    soup = BeautifulSoup(content)
    
    df2.loc[df2['id'] == missing_film_ids.iloc[i], 'director'] = scrape_director(soup)
    df2.loc[df2['id'] == missing_film_ids.iloc[i], 'writer'] = scrape_writer(soup)
    df2.loc[df2['id'] == missing_film_ids.iloc[i], 'imdb_rating'] = scrape_imdb_rating(soup)
    df2.loc[df2['id'] == missing_film_ids.iloc[i], 'imdb_rating_count'] = scrape_rating_count(soup)
    df2.loc[df2['id'] == missing_film_ids.iloc[i], 'metascore'] = scrape_metascore(soup)
    df2.loc[df2['id'] == missing_film_ids.iloc[i], 'user_review_count'] = scrape_user_review_count(soup)
    df2.loc[df2['id'] == missing_film_ids.iloc[i], 'critic_review_count'] = scrape_critic_review_count(soup)
    df2.loc[df2['id'] == missing_film_ids.iloc[i], 'color'] = scrape_color(soup)
    df2.loc[df2['id'] == missing_film_ids.iloc[i], 'aspect_ratio'] = scrape_aspect_ratio(soup)

# %% [markdown]
# Everything looks fine

# %%
df2[df2['id'].isin(missing_film_ids)]
# Out:
#               id                 director  \
# 559    tt0448115        David F. Sandberg
# 4609   tt9354842        Michael Fimognari
# 4704  tt11045422  Rakeysh Omprakash Mehra
#
#                                         writer imdb_rating imdb_rating_count  \
# 559      Henry Gayden;Bill Parker;Darren Lemke         7.0            302935
# 4609  Sofia Alvarez;J. Mills Goodloe;Jenny Han         6.0             34966
# 4704               Vijay Maurya;Anjum Rajabali         5.2             33954
#
#      metascore user_review_count critic_review_count  color aspect_ratio
# 559         71              2157                 395  Color     2.39 : 1
# 4609        54               167                  58  Color     2.39 : 1
# 4704       NaN               752                  19  Color          NaN

# %% [markdown]
# ### Missing user review counts

# %%
df2[df2['user_review_count'].isnull()]
# Out:
#               id                      director  \
# 2720  tt10280276                  David Dhawan
# 2730   tt8695030                  Jim Jarmusch
# 3847   tt0091225                 Willard Huyck
# 4091   tt2178470                Ayan Mukherjee
# 4578   tt0096332                Philip Kaufman
# 4751  tt13491110              Mahesh Manjrekar
# 4901   tt0827503  Cem Yilmaz;Ali Taner Baltaci
#
#                                                  writer imdb_rating  \
# 2720                          Rumi Jaffery;Farhad Samji         4.2
# 2730                                       Jim Jarmusch         5.5
# 3847             Willard Huyck;Steve Gerber;Gloria Katz         4.7
# 4091                       Hussain Dalal;Ayan Mukherjee         7.2
# 4578  Milan Kundera;Philip Kaufman;Jean-Claude Carri...         7.3
# 4751  Siddharth Salvi;Mahesh Manjrekar;Abhijeet Shir...         7.6
# 4901                                         Cem Yilmaz         7.4
#
#      imdb_rating_count metascore user_review_count critic_review_count color  \
# 2720             72596       NaN               NaN                  25   NaN
# 2730             72358        53               NaN                 345   NaN
# 3847             45726        28               NaN                 112   NaN
# 4091             41919       NaN               NaN                  28   NaN
# 4578             35328        73               NaN                  58   NaN
# 4751             33511       NaN               NaN                   8   NaN
# 4901             31833       NaN               NaN                   5   NaN
#
#      aspect_ratio
# 2720          NaN
# 2730          NaN
# 3847          NaN
# 4091          NaN
# 4578          NaN
# 4751          NaN
# 4901          NaN

# %% [markdown]
# Let's extract the IDs of these films in a Pandas series

# %%
missing_user_review_ids = df2.loc[df2["user_review_count"].isnull(), "id"]

# %% [markdown]
# Let's scrape the user review count again

# %%
for i in range(len(missing_user_review_ids)):
    content = requests.get(f"https://www.imdb.com/title/{missing_user_review_ids.iloc[i]}").content
    soup = BeautifulSoup(content)
    
    df2.loc[df2['id'] == missing_user_review_ids.iloc[i], 'user_review_count'] = scrape_user_review_count(soup)

# %% [markdown]
# We managed to retrieve the user review count for most of those films.

# %%
df2[df2["id"].isin(missing_user_review_ids)]
# Out:
#               id                      director  \
# 2720  tt10280276                  David Dhawan
# 2730   tt8695030                  Jim Jarmusch
# 3847   tt0091225                 Willard Huyck
# 4091   tt2178470                Ayan Mukherjee
# 4578   tt0096332                Philip Kaufman
# 4751  tt13491110              Mahesh Manjrekar
# 4901   tt0827503  Cem Yilmaz;Ali Taner Baltaci
#
#                                                  writer imdb_rating  \
# 2720                          Rumi Jaffery;Farhad Samji         4.2
# 2730                                       Jim Jarmusch         5.5
# 3847             Willard Huyck;Steve Gerber;Gloria Katz         4.7
# 4091                       Hussain Dalal;Ayan Mukherjee         7.2
# 4578  Milan Kundera;Philip Kaufman;Jean-Claude Carri...         7.3
# 4751  Siddharth Salvi;Mahesh Manjrekar;Abhijeet Shir...         7.6
# 4901                                         Cem Yilmaz         7.4
#
#      imdb_rating_count metascore user_review_count critic_review_count color  \
# 2720             72596       NaN              2984                  25   NaN
# 2730             72358        53              1533                 345   NaN
# 3847             45726        28               363                 112   NaN
# 4091             41919       NaN               159                  28   NaN
# 4578             35328        73               143                  58   NaN
# 4751             33511       NaN               NaN                   8   NaN
# 4901             31833       NaN                16                   5   NaN
#
#      aspect_ratio
# 2720          NaN
# 2730          NaN
# 3847          NaN
# 4091          NaN
# 4578          NaN
# 4751          NaN
# 4901          NaN

# %% [markdown]
# # Third dataframe
